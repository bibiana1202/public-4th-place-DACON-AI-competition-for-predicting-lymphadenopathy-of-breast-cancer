# %% [markdown]
# # cat_col 상관관계 분석

# %%
import pandas as pd
import numpy as np

train_df = pd.read_csv(r'C:\A\breastCancer\ml/train.csv')
test_df = pd.read_csv(r"C:\A\breastCancer\ml/test.csv")

# %%
import os
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False
if not IN_COLAB:
    os.chdir("..")
from sklearn.datasets import fetch_covtype
import random
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
import os
import warnings
warnings.filterwarnings("ignore")

# %%
# CAT_COL fillna
train_df['NG']= train_df['NG'].fillna(2)
train_df['HG']= train_df['HG'].fillna(2)
train_df['HG_score_1']= train_df['HG_score_1'].fillna(3)
train_df['HG_score_2']= train_df['HG_score_2'].fillna(2)
train_df['HG_score_3']= train_df['HG_score_3'].fillna(1)
train_df['DCIS_or_LCIS_type']= train_df['DCIS_or_LCIS_type'].fillna(2)
train_df['T_category']= train_df['T_category'].fillna(1)
train_df['ER']= train_df['ER'].fillna(1)
train_df['PR']= train_df['PR'].fillna(1)
train_df['HER2']= train_df['HER2'].fillna(0)
train_df['HER2_IHC']= train_df['HER2_IHC'].fillna(2)
train_df['HER2_SISH']= train_df['HER2_SISH'].fillna(0)
train_df['BRCA_mutation']= train_df['BRCA_mutation'].fillna(0)

# NUL_COL fillna
# median
train_df['size of cancers'] = train_df['size of cancers'].fillna(train_df['size of cancers'].median())
train_df['ER_Allred_score'] = train_df['ER_Allred_score'].fillna(train_df['ER_Allred_score'].median())
train_df['PR_Allred_score'] = train_df['PR_Allred_score'].fillna(train_df['PR_Allred_score'].median())
train_df['KI-67_LI_percent'] = train_df['KI-67_LI_percent'].fillna(train_df['KI-67_LI_percent'].median())
train_df['HER2_SISH_ratio'] = train_df['HER2_SISH_ratio'].fillna(train_df['HER2_SISH_ratio'].median())


target_name = ['N_category']

# 명목형 변수
cat_col_names = [
    'dx','location of cancers', 'number of cancers', 'NG','HG','HG_score_1','HG_score_2','HG_score_3','DCIS_or_LCIS','DCIS_or_LCIS_type','T_category','ER','PR','HER2','HER2_IHC','HER2_SISH',"BRCA_mutation"
]

for col_name in cat_col_names:
    cat_values = np.unique(train_df[col_name])
    
    #print(f"{col_name}: {cat_values}\n")


# 수치형 변수
num_col_names = [
    'age','size of cancers','ER_Allred_score','PR_Allred_score','KI-67_LI_percent','HER2_SISH_ratio'
]

feature_columns = (
    num_col_names + cat_col_names + target_name)

train_df = train_df.loc[:,feature_columns]


test = test_df.loc[:,num_col_names + cat_col_names]


X = train_df.loc[:,cat_col_names]
y = train_df.loc[:,target_name]
# Out:
# [autoreload of sklearn.base failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: clone() requires a code object with 0 free vars, not 3
# ]
# [autoreload of sklearn.utils failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\sklearn\utils\__init__.py", line 27, in <module>
#     from .fixes import np_version, parse_version
# ImportError: cannot import name 'parse_version' from 'sklearn.utils.fixes' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\sklearn\utils\fixes.py)
# ]
# [autoreload of scipy.sparse.base failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\base.py", line 4, in <module>
#     from .sputils import (isdense, isscalarlike, isintlike,
# ImportError: cannot import name 'asmatrix' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of scipy.sparse.sputils failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py", line 8, in <module>
#     from scipy._lib._util import prod
# ImportError: cannot import name 'prod' from 'scipy._lib._util' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\_lib\_util.py)
# ]
# [autoreload of scipy.sparse.compressed failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\compressed.py", line 14, in <module>
#     from ._sparsetools import (get_csr_submatrix, csr_sample_offsets, csr_todense,
# ImportError: cannot import name 'csr_row_index' from 'scipy.sparse._sparsetools' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\_sparsetools.cp37-win_amd64.pyd)
# ]
# [autoreload of scipy.sparse.data failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\data.py", line 12, in <module>
#     from .sputils import isscalarlike, validateaxis, matrix
# ImportError: cannot import name 'matrix' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of scipy.sparse.dia failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\dia.py", line 11, in <module>
#     from .sputils import (isshape, upcast_char, getdtype, get_index_dtype,
# ImportError: cannot import name 'matrix' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of scipy.sparse.lil failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\lil.py", line 14, in <module>
#     from .sputils import (getdtype, isshape, isscalarlike, upcast_scalar,
# ImportError: cannot import name 'asmatrix' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of scipy.sparse.coo failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\coo.py", line 15, in <module>
#     from .sputils import (upcast, upcast_char, to_native, isshape, getdtype,
# ImportError: cannot import name 'getdata' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of scipy.sparse.bsr failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\bsr.py", line 14, in <module>
#     from .sputils import (isshape, getdtype, getdata, to_native, upcast,
# ImportError: cannot import name 'getdata' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of sklearn.utils.class_weight failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: compute_class_weight() requires a code object with 0 free vars, not 3
# ]
# [autoreload of sklearn.utils.fixes failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\sklearn\utils\fixes.py", line 108, in <module>
#     class loguniform(scipy.stats.reciprocal):
# AttributeError: module 'scipy' has no attribute 'stats'
# ]
# [autoreload of scipy.stats failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\stats\__init__.py", line 452, in <module>
#     from ._bootstrap import bootstrap
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\stats\_bootstrap.py", line 7, in <module>
#     from scipy.stats.stats import _broadcast_concatenate
# ImportError: cannot import name '_broadcast_concatenate' from 'scipy.stats.stats' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\stats\stats.py)
# ]
# [autoreload of scipy.stats.stats failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\stats\stats.py", line 47, in <module>
#     from ._stats import (_kendall_dis, _toint64, _weightedrankedtau,
# ImportError: cannot import name '_local_correlations' from 'scipy.stats._stats' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\stats\_stats.cp37-win_amd64.pyd)
# ]
# [autoreload of scipy.special failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\special\__init__.py", line 649, in <module>
#     from ._logsumexp import logsumexp, softmax, log_softmax
# ImportError: cannot import name 'log_softmax' from 'scipy.special._logsumexp' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\special\_logsumexp.py)
# ]
# [autoreload of scipy.linalg.blas failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: get_blas_funcs() requires a code object with 0 free vars, not 2
# ]
# [autoreload of scipy.linalg.lapack failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\linalg\lapack.py", line 885, in <module>
#     ssyevx, dsyevx, cheevx, zheevx,
# NameError: name 'ssyevx' is not defined
# ]
# [autoreload of scipy.misc.doccer failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: docformat() requires a code object with 0 free vars, not 2
# ]
# [autoreload of scipy.interpolate._fitpack_impl failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\interpolate\_fitpack_impl.py", line 38, in <module>
#     dfitpack_int = dfitpack.types.intvar.dtype
# AttributeError: module 'scipy.interpolate.dfitpack' has no attribute 'types'
# ]
# [autoreload of scipy.interpolate.fitpack2 failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\interpolate\fitpack2.py", line 31, in <module>
#     dfitpack_int = dfitpack.types.intvar.dtype
# AttributeError: module 'scipy.interpolate.dfitpack' has no attribute 'types'
# ]
# [autoreload of scipy.spatial.kdtree failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of scipy.spatial.distance failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _validate_wminkowski_kwargs() requires a code object with 0 free vars, not 3
# ]
# [autoreload of scipy.sparse.linalg.isolve.iterative failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\linalg\isolve\iterative.py", line 150, in <module>
#     def bicg(A, b, x0=None, tol=1e-5, maxiter=None, M=None, callback=None, atol=None):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\_lib\_threadsafety.py", line 59, in decorator
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\_lib\_threadsafety.py", line 47, in decorate
# AttributeError: module 'scipy' has no attribute '_lib'
# ]
# [autoreload of scipy.sparse.linalg.interface failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\linalg\interface.py", line 48, in <module>
#     from scipy.sparse.sputils import isshape, isintlike, asmatrix, is_pydata_spmatrix
# ImportError: cannot import name 'asmatrix' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of scipy.sparse.linalg.isolve.utils failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\linalg\isolve\utils.py", line 7, in <module>
#     from scipy.sparse.sputils import asmatrix
# ImportError: cannot import name 'asmatrix' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of scipy.sparse.linalg.dsolve.linsolve failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\linalg\dsolve\linsolve.py", line 7, in <module>
#     from scipy.sparse.sputils import is_pydata_spmatrix
# ImportError: cannot import name 'is_pydata_spmatrix' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of scipy.sparse.linalg.eigen.arpack.arpack failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py", line 50, in <module>
#     from scipy.sparse.sputils import isdense, is_pydata_spmatrix
# ImportError: cannot import name 'is_pydata_spmatrix' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of scipy.sparse.linalg.matfuncs failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\linalg\matfuncs.py", line 21, in <module>
#     from scipy.sparse.sputils import is_pydata_spmatrix
# ImportError: cannot import name 'is_pydata_spmatrix' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of scipy.sparse.linalg._expm_multiply failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\linalg\_expm_multiply.py", line 9, in <module>
#     from scipy.sparse.sputils import is_pydata_spmatrix
# ImportError: cannot import name 'is_pydata_spmatrix' from 'scipy.sparse.sputils' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\sparse\sputils.py)
# ]
# [autoreload of scipy.optimize.cobyla failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: fmin_cobyla() requires a code object with 0 free vars, not 1
# ]
# [autoreload of scipy.optimize._linprog failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\optimize\_linprog.py", line 29, in <module>
#     from ._linprog_util import (
# ImportError: cannot import name '_LPProblem' from 'scipy.optimize._linprog_util' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\optimize\_linprog_util.py)
# ]
# [autoreload of scipy.optimize._linprog_util failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\optimize\_linprog_util.py", line 9, in <module>
#     from scipy.optimize._remove_redundancy import (
# ImportError: cannot import name '_remove_redundancy_svd' from 'scipy.optimize._remove_redundancy' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\optimize\_remove_redundancy.py)
# ]
# [autoreload of scipy.integrate failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\integrate\__init__.py", line 95, in <module>
#     from ._ivp import (solve_ivp, OdeSolution, DenseOutput,
# ImportError: cannot import name 'DOP853' from 'scipy.integrate._ivp' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\integrate\_ivp\__init__.py)
# ]
# [autoreload of scipy.integrate._ode failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\integrate\_ode.py", line 95, in <module>
#     _dop_int_dtype = _dop.types.intvar.dtype
# AttributeError: module 'scipy.integrate._dop' has no attribute 'types'
# ]
# [autoreload of scipy.integrate._ivp failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\integrate\_ivp\__init__.py", line 3, in <module>
#     from .rk import RK23, RK45, DOP853
# ImportError: cannot import name 'DOP853' from 'scipy.integrate._ivp.rk' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\integrate\_ivp\rk.py)
# ]
# [autoreload of scipy.integrate._ivp.ivp failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\integrate\_ivp\ivp.py", line 5, in <module>
#     from .rk import RK23, RK45, DOP853
# ImportError: cannot import name 'DOP853' from 'scipy.integrate._ivp.rk' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\integrate\_ivp\rk.py)
# ]
# [autoreload of scipy.stats._continuous_distns failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: fit() requires a code object with 0 free vars, not 1
# ]
# [autoreload of scipy.stats._stats_mstats_common failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _asdict() requires a code object with 0 free vars, not 2
# ]
# [autoreload of scipy.stats._rvs_sampling failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\stats\_rvs_sampling.py", line 4, in <module>
#     from scipy.interpolate import CubicHermiteSpline
# ImportError: cannot import name 'CubicHermiteSpline' from 'scipy.interpolate' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\interpolate\__init__.py)
# ]
# [autoreload of scipy.stats.morestats failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\stats\morestats.py", line 16, in <module>
#     from .stats import find_repeats, _contains_nan, _normtest_finish
# ImportError: cannot import name '_normtest_finish' from 'scipy.stats.stats' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\stats\stats.py)
# ]
# [autoreload of scipy.stats.kde failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\stats\kde.py", line 35, in <module>
#     from ._stats import gaussian_kernel_estimate
# ImportError: cannot import name 'gaussian_kernel_estimate' from 'scipy.stats._stats' (c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\scipy\stats\_stats.cp37-win_amd64.pyd)
# ]
# [autoreload of sklearn.utils.validation failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: assert_all_finite() requires a code object with 0 free vars, not 4
# ]
# [autoreload of sklearn.datasets._base failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: load_files() requires a code object with 0 free vars, not 4
# ]
# [autoreload of sklearn.datasets._covtype failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: fetch_covtype() requires a code object with 0 free vars, not 4
# ]
# [autoreload of sklearn.datasets._kddcup99 failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
# ...
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 4
# ]
# [autoreload of sklearn.linear_model._perceptron failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 4
# ]
# [autoreload of sklearn.linear_model._ransac failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 4
# ]
# [autoreload of sklearn.linear_model._theil_sen failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 4
# ]
# [autoreload of sklearn.decomposition._dict_learning failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: sparse_encode() requires a code object with 0 free vars, not 4
# ]
# [autoreload of sklearn.decomposition._truncated_svd failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 4
# ]
# [autoreload of sklearn.decomposition._fastica failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: fastica() requires a code object with 0 free vars, not 4
# ]
# [autoreload of sklearn.decomposition._factor_analysis failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 4
# ]
# [autoreload of sklearn.tree._export failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: plot_tree() requires a code object with 0 free vars, not 4
# ]
# [autoreload of sklearn.ensemble._bagging failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 4
# ]
# [autoreload of sklearn.ensemble._iforest failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 4
# ]
# [autoreload of sklearn.ensemble._weight_boosting failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 4
# ]
# [autoreload of sklearn.ensemble._gb failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 4
# ]
# [autoreload of sklearn.dummy failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 4
# ]
# [autoreload of sklearn.ensemble._voting failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 4
# ]
# [autoreload of sklearn.ensemble._stacking failed: Traceback (most recent call last):
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "c:\Users\wew12\Anaconda3\envs\ed4\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 4
# ]

# %%
import re
df = train_df.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                1000 non-null   int64
#  1   sizeofcancers      1000 non-null   float64
#  2   ER_Allred_score    1000 non-null   float64
#  3   PR_Allred_score    1000 non-null   float64
#  4   KI67_LI_percent    1000 non-null   float64
#  5   HER2_SISH_ratio    1000 non-null   float64
#  6   dx                 1000 non-null   int64
#  7   locationofcancers  1000 non-null   int64
#  8   numberofcancers    1000 non-null   int64
#  9   NG                 1000 non-null   float64
#  10  HG                 1000 non-null   float64
#  11  HG_score_1         1000 non-null   float64
#  12  HG_score_2         1000 non-null   float64
#  13  HG_score_3         1000 non-null   float64
#  14  DCIS_or_LCIS       1000 non-null   int64
#  15  DCIS_or_LCIS_type  1000 non-null   float64
#  16  T_category         1000 non-null   float64
#  17  ER                 1000 non-null   float64
#  18  PR                 1000 non-null   float64
#  19  HER2               1000 non-null   float64
#  20  HER2_IHC           1000 non-null   float64
#  21  HER2_SISH          1000 non-null   float64
#  22  BRCA_mutation      1000 non-null   float64
#  23  N_category         1000 non-null   int64
# dtypes: float64(18), int64(6)
# memory usage: 187.6 KB

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dx                   1000 non-null   int64
#  1   location of cancers  1000 non-null   int64
#  2   number of cancers    1000 non-null   int64
#  3   NG                   1000 non-null   float64
#  4   HG                   1000 non-null   float64
#  5   HG_score_1           1000 non-null   float64
#  6   HG_score_2           1000 non-null   float64
#  7   HG_score_3           1000 non-null   float64
#  8   DCIS_or_LCIS         1000 non-null   int64
#  9   DCIS_or_LCIS_type    1000 non-null   float64
#  10  T_category           1000 non-null   float64
#  11  ER                   1000 non-null   float64
#  12  PR                   1000 non-null   float64
#  13  HER2                 1000 non-null   float64
#  14  HER2_IHC             1000 non-null   float64
#  15  HER2_SISH            1000 non-null   float64
#  16  BRCA_mutation        1000 non-null   float64
# dtypes: float64(13), int64(4)
# memory usage: 132.9 KB

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   N_category  1000 non-null   int64
# dtypes: int64(1)
# memory usage: 7.9 KB

# %%
import pandas as pd
from scipy.stats import chi2_contingency

dic_result = {
    '독립변수':[],
    '카이제곱 통계량':[],
    'p-value':[],
    'df':[],
    '기댓값 행렬':[]
}
df_expected = pd.DataFrame()

for i in X.columns:
  dic_result['독립변수'].append(i)
  A = np.array(X[i])
  B = np.array(y['N_category'])

  #crosstab 객체의 margins=False여야 
  crosstab=pd.crosstab(A, B, margins=False)
  # 교차분석 결과값들 일괄계산
  # correction=True를 적용하면 Yates' correction이 적용 되어 검정통계량이 보수적으로 더 낮게 나옴
  result=chi2_contingency(observed=crosstab, correction=False)
  dic_result['카이제곱 통계량'].append(result[0])
  dic_result['p-value'].append(result[1])
  dic_result['df'].append(result[2])
  dic_result['기댓값 행렬'].append(result[3])
  df= pd.DataFrame(result[3]).rename(index={0:i}, columns={0:'림프절전이X', 1:'림프절전이O'})
  df_expected= pd.concat([df_expected,df])

df_result = pd.DataFrame(dic_result)

# %%
df_result
# Out:
#                    독립변수    카이제곱 통계량       p-value  df  \
# 0                    dx   10.369261  1.567452e-02   3
# 1   location of cancers    0.910054  6.344309e-01   2
# 2     number of cancers   72.307456  1.841503e-17   1
# 3                    NG  170.987072  7.423847e-38   2
# 4                    HG   55.158552  1.053107e-12   2
# 5            HG_score_1   48.170307  3.466976e-11   2
# 6            HG_score_2   97.981359  5.291980e-22   2
# 7            HG_score_3   20.783127  1.167775e-04   3
# 8          DCIS_or_LCIS  185.077813  6.469393e-41   2
# 9     DCIS_or_LCIS_type   28.714687  8.386527e-08   1
# 10           T_category  125.574647  3.439903e-26   4
# 11                   ER    0.007334  9.317551e-01   1
# 12                   PR    2.513120  1.129022e-01   1
# 13                 HER2    8.181040  4.233048e-03   1
# 14             HER2_IHC    2.325276  5.076960e-01   3
# 15            HER2_SISH    9.451716  2.109517e-03   1
# 16        BRCA_mutation    0.895417  3.440136e-01   1
#
#                                                기댓값 행렬
# 0   [[416.502, 440.498], [31.59, 33.41], [4.86, 5....
# 1   [[229.392, 242.608], [240.57, 254.43], [16.038...
# 2              [[421.362, 445.638], [64.638, 68.362]]
# 3   [[95.256, 100.744], [262.926, 278.074], [127.8...
# 4   [[138.024, 145.976], [255.636, 270.364], [92.3...
# 5   [[40.824, 43.176], [100.116, 105.884], [345.06...
# 6   [[67.554, 71.446], [287.226, 303.774], [131.22...
# 7   [[353.808, 374.192], [76.302, 80.698], [54.432...
# 8   [[291.114, 307.886], [40.338, 42.662], [154.54...
# 9              [[33.534, 35.466], [452.466, 478.534]]
# 10  [[34.506, 36.494], [293.544, 310.456], [148.23...
# 11                 [[87.48, 92.52], [398.52, 421.48]]
# 12           [[173.988, 184.012], [312.012, 329.988]]
# 13           [[367.416, 388.584], [118.584, 125.416]]
# 14  [[121.986, 129.014], [152.604, 161.396], [169....
# 15             [[470.448, 497.552], [15.552, 16.448]]
# 16               [[484.056, 511.944], [1.944, 2.056]]

# %%
df_result.to_csv(r'C:\A\breastCancer\ml/output/coll/df_result_cat_corrleation_3.csv')

# %%
df_expected
# Out:
#                       림프절전이X   림프절전이O
# dx                   416.502  440.498
# 1                     31.590   33.410
# 2                      4.860    5.140
# 3                     33.048   34.952
# location of cancers  229.392  242.608
# 1                    240.570  254.430
# 2                     16.038   16.962
# number of cancers    421.362  445.638
# 1                     64.638   68.362
# NG                    95.256  100.744
# 1                    262.926  278.074
# 2                    127.818  135.182
# HG                   138.024  145.976
# 1                    255.636  270.364
# 2                     92.340   97.660
# HG_score_1            40.824   43.176
# 1                    100.116  105.884
# 2                    345.060  364.940
# HG_score_2            67.554   71.446
# 1                    287.226  303.774
# 2                    131.220  138.780
# HG_score_3           353.808  374.192
# 1                     76.302   80.698
# 2                     54.432   57.568
# 3                      1.458    1.542
# DCIS_or_LCIS         291.114  307.886
# 1                     40.338   42.662
# 2                    154.548  163.452
# DCIS_or_LCIS_type     33.534   35.466
# 1                    452.466  478.534
# T_category            34.506   36.494
# 1                    293.544  310.456
# 2                    148.230  156.770
# 3                      7.776    8.224
# 4                      1.944    2.056
# ER                    87.480   92.520
# 1                    398.520  421.480
# PR                   173.988  184.012
# 1                    312.012  329.988
# HER2                 367.416  388.584
# 1                    118.584  125.416
# HER2_IHC             121.986  129.014
# 1                    152.604  161.396
# 2                    169.128  178.872
# 3                     42.282   44.718
# HER2_SISH            470.448  497.552
# 1                     15.552   16.448
# BRCA_mutation        484.056  511.944
# 1                      1.944    2.056

# %%
df_expected.to_csv(r'C:\A\breastCancer\ml\output\coll/df_expected_cat_corrleation_3.csv')

# %% [markdown]
# # num_col 상관관계분석

# %%
import os
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False
if not IN_COLAB:
    os.chdir("..")
from sklearn.datasets import fetch_covtype
import random
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
import os
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np

train_df = pd.read_csv(r'C:\A\breastCancer\ml/train.csv')
test_df = pd.read_csv(r"C:\A\breastCancer\ml/test.csv")

# %%
# CAT_COL fillna
train_df['NG']= train_df['NG'].fillna(2)
train_df['HG']= train_df['HG'].fillna(2)
train_df['HG_score_1']= train_df['HG_score_1'].fillna(3)
train_df['HG_score_2']= train_df['HG_score_2'].fillna(2)
train_df['HG_score_3']= train_df['HG_score_3'].fillna(1)
train_df['DCIS_or_LCIS_type']= train_df['DCIS_or_LCIS_type'].fillna(2)
train_df['T_category']= train_df['T_category'].fillna(1)
train_df['ER']= train_df['ER'].fillna(1)
train_df['PR']= train_df['PR'].fillna(1)
train_df['HER2']= train_df['HER2'].fillna(0)
train_df['HER2_IHC']= train_df['HER2_IHC'].fillna(2)
train_df['HER2_SISH']= train_df['HER2_SISH'].fillna(0)
train_df['BRCA_mutation']= train_df['BRCA_mutation'].fillna(0)

# NUL_COL fillna
# median
train_df['size of cancers'] = train_df['size of cancers'].fillna(train_df['size of cancers'].median())
train_df['ER_Allred_score'] = train_df['ER_Allred_score'].fillna(train_df['ER_Allred_score'].median())
train_df['PR_Allred_score'] = train_df['PR_Allred_score'].fillna(train_df['PR_Allred_score'].median())
train_df['KI-67_LI_percent'] = train_df['KI-67_LI_percent'].fillna(train_df['KI-67_LI_percent'].median())
train_df['HER2_SISH_ratio'] = train_df['HER2_SISH_ratio'].fillna(train_df['HER2_SISH_ratio'].median())


target_name = ['N_category']

# 명목형 변수
cat_col_names = [
    'dx','location of cancers', 'number of cancers', 'NG','HG','HG_score_1','HG_score_2','HG_score_3','DCIS_or_LCIS','DCIS_or_LCIS_type','T_category','ER','PR','HER2','HER2_IHC','HER2_SISH',"BRCA_mutation"
]

for col_name in cat_col_names:
    cat_values = np.unique(train_df[col_name])
    
    #print(f"{col_name}: {cat_values}\n")


# 수치형 변수
num_col_names = [
    'age','size of cancers','ER_Allred_score','PR_Allred_score','KI-67_LI_percent','HER2_SISH_ratio'
]

feature_columns = (
    num_col_names + cat_col_names + target_name)

train_df = train_df.loc[:,feature_columns]


test = test_df.loc[:,num_col_names + cat_col_names]


X = train_df.loc[:,num_col_names]
y = train_df.loc[:,target_name]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1000 non-null   int64
#  1   size of cancers   1000 non-null   float64
#  2   ER_Allred_score   1000 non-null   float64
#  3   PR_Allred_score   1000 non-null   float64
#  4   KI-67_LI_percent  1000 non-null   float64
#  5   HER2_SISH_ratio   1000 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 47.0 KB

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   N_category  1000 non-null   int64
# dtypes: int64(1)
# memory usage: 7.9 KB

# %%
import pandas as pd
import scipy.stats as stats

dic_result = {
    '독립변수':[],
    'correlation':[],
    'p-value':[]
}
df_expected = pd.DataFrame()

for i in X.columns:
  dic_result['독립변수'].append(i)
  A = (X[i])
  B = y['N_category']
  result = stats.pearsonr(A,B)
  dic_result['correlation'].append(result[0])
  dic_result['p-value'].append(result[1])

df_result = pd.DataFrame(dic_result)

# %%
df_result
# Out:
#                독립변수  correlation       p-value
# 0               age     0.069017  2.908133e-02
# 1   size of cancers     0.287994  1.494569e-20
# 2   ER_Allred_score     0.054848  8.299414e-02
# 3   PR_Allred_score    -0.047400  1.341620e-01
# 4  KI-67_LI_percent     0.188617  1.841873e-09
# 5   HER2_SISH_ratio     0.034231  2.795056e-01

# %%
df_result.to_csv(r'C:\A\breastCancer\ml\output\coll/df_result_num_corrleation_3.csv')

# %% [markdown]
# # 분류 시작

# %%
SEED = 88
NSPLIT = 10

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(SEED) # Seed 고정

# %%
"""
# split the dataset into the training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = SEED)
"""

from sklearn.model_selection import KFold

X = np.array(X)                 #np.array(df.iloc[:, :-1]) # class 열 제외한 feature 열들 모음 -> array 변환
y = np.array(y)                           #df['class']

# %%
# split 개수, 셔플 여부 및 seed 설정
kf = KFold(n_splits = NSPLIT, shuffle = True, random_state = SEED)

# split 개수 스텝 만큼 train, test 데이터셋을 매번 분할
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %% [markdown]
# ##lightGBM

# %%
import lightgbm as lgb

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

accuracy_history = []
f1_score_history = []

# K-fold 검증 과정으로 실제 랜덤 포레스트 모델을 학습하여 정확도 평균을 내는 방법
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    
    clf = lgb.LGBMClassifier(n_estimators=5, random_state=SEED) # 모델 선언
    clf.fit(X_train,y_train) # 모델 학습
    y_pred=clf.predict(X_test) # 예측 라벨
    accuracy_history.append(accuracy_score(y_pred, y_test)) # 정확도 측정 및 기록
    f1_score_history.append(f1_score(y_pred, y_test)) # 정확도 측정 및 기록

print("accuracy 각 분할의 정확도 기록 :", accuracy_history)
print("accuracy 평균 정확도 :", np.mean(accuracy_history))

print("f1_score 각 분할의 정확도 기록 :", f1_score_history)
print("f1_score 평균 정확도 :", np.mean(f1_score_history))
# Out:
# accuracy 각 분할의 정확도 기록 : [0.85, 0.79, 0.73, 0.77, 0.75, 0.71, 0.77, 0.77, 0.75, 0.79]
# accuracy 평균 정확도 : 0.768
# f1_score 각 분할의 정확도 기록 : [0.8421052631578948, 0.8073394495412846, 0.7157894736842104, 0.7722772277227723, 0.7252747252747253, 0.7184466019417476, 0.8067226890756303, 0.7766990291262137, 0.7368421052631577, 0.817391304347826]
# f1_score 평균 정확도 : 0.7718887869135462

# %% [markdown]
# ## catboost classififier

# %%
# !pip install catboost

# %%
from catboost import CatBoostClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

accuracy_history = []
f1_score_history = []

# K-fold 검증 과정으로 실제 랜덤 포레스트 모델을 학습하여 정확도 평균을 내는 방법
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    clf = CatBoostClassifier(
      iterations=5, 
      learning_rate=0.1, 
      loss_function='CrossEntropy',
      random_state=SEED) # 모델 선언

    clf.fit(X_train,y_train) # 모델 학습
    y_pred=clf.predict(X_test) # 예측 라벨
    accuracy_history.append(accuracy_score(y_pred, y_test)) # 정확도 측정 및 기록
    f1_score_history.append(f1_score(y_pred, y_test)) # 정확도 측정 및 기록

print("accuracy 각 분할의 정확도 기록 :", accuracy_history)
print("accuracy 평균 정확도 :", np.mean(accuracy_history))

print("f1_score 각 분할의 정확도 기록 :", f1_score_history)
print("f1_score 평균 정확도 :", np.mean(f1_score_history))

# %% [markdown]
# ## test preidiction

# %%
test_df_id = test_df.loc[:,'ID']
len(test_df_id),type(test_df_id)
# Out:
# (250, pandas.core.series.Series)

# %%
array = np.array(test_df_id.values)
len(array),type(array)
# Out:
# (250, numpy.ndarray)

# %%
test_pred = clf.predict(test)
len(test_pred),type(test_pred)
# Out:
# (250, numpy.ndarray)

# %%
dic_pred={
    'ID' : array,
    'N_category':test_pred
}

# %%
df_test_pred = pd.DataFrame(dic_pred)

# %%
df_test_pred
# Out:
#              ID  N_category
# 0    BC_01_0011           1
# 1    BC_01_0220           1
# 2    BC_01_0233           0
# 3    BC_01_0258           0
# 4    BC_01_0260           1
# ..          ...         ...
# 245  BC_01_3328           1
# 246  BC_01_3404           0
# 247  BC_01_3418           0
# 248  BC_01_3438           0
# 249  BC_01_3446           0
#
# [250 rows x 2 columns]

# %%
df_test_pred.to_csv(f'/content/drive/MyDrive/project/BreastCancer/ml/output/lgbm_{SEED}_{f1score}.csv')

# %%
"""import lightgbm as lgb
clf = lgb.LGBMClassifier()
clf
clf.fit(X_train,y_train)
# predict the results
y_pred=clf.predict(X_test)
# view accuracy
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

accuracy=accuracy_score(y_pred, y_test)
print('LightGBM Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_pred)))
y_pred_train = clf.predict(X_train)
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))


# print the scores on training and test set
print('Training set score: {:.4f}'.format(clf.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf.score(X_test, y_test)))
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
f1score=f1_score(y_pred, y_test)
print('LightGBM Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_pred)))
print('LightGBM Model f1score score: {0:0.4f}'.format(f1_score(y_pred, y_test)))"""

# %%
"""from catboost import CatBoostClassifier
clf = CatBoostClassifier(
    iterations=5, 
    learning_rate=0.1, 
    loss_function='CrossEntropy'
)
clf.fit(X_train,y_train)
# predict the results
y_pred=clf.predict(X_test)
# view accuracy
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
print('catboost classififier Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_pred)))
y_pred_train = clf.predict(X_train)
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# print the scores on training and test set

print('Training set score: {:.4f}'.format(clf.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf.score(X_test, y_test)))
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
print('catboost classififier Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_pred)))"""
