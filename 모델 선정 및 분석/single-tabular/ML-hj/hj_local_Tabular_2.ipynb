# %%
import random
import os
import numpy as np


# 시드 정하기!!!!!!!

CFG = {
    'SEED':42,
    'NSPLIT' :10

}

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(CFG['SEED']) # Seed 고정

# %%
import os
from sklearn.datasets import fetch_covtype
import random
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
import os
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np

train_df = pd.read_csv(r'C:\A\breastCancer\ml/train.csv')
test_df = pd.read_csv(r"C:\A\breastCancer\ml/test.csv")

# median
train_df['size of cancers'] = train_df['size of cancers'].fillna(train_df['size of cancers'].median())
train_df = train_df.fillna(0)

test_df['size of cancers'] = test_df['size of cancers'].fillna(train_df['size of cancers'].median())
test_df = test_df.fillna(0)


target_name = ['N_category']
# 명목형 변수
cat_col_names = [
    # 기본
    #'dx','location of cancers', 'number of cancers', 'NG','HG','HG_score_1','HG_score_2','HG_score_3','DCIS_or_LCIS','DCIS_or_LCIS_type','T_category','ER','PR','HER2','HER2_IHC','HER2_SISH',"BRCA_mutation"
     #0 : 5개 제거(location of cancers,ER,PR,HER2_IHC,BRCA_mutation)
    'dx', 'number of cancers', 'NG','HG','HG_score_1','HG_score_2','HG_score_3','DCIS_or_LCIS','DCIS_or_LCIS_type','T_category','HER2','HER2_SISH'
    # 1 : 3개 제거(location of cancers,ER,BRCA_mutation)
    #'dx', 'number of cancers', 'NG','HG','HG_score_1','HG_score_2','HG_score_3','DCIS_or_LCIS','DCIS_or_LCIS_type','T_category','HER2','HER2_SISH','PR','HER2_IHC'
    # 2 : 2개 제거((location of cancers,ER)
    #'dx', 'number of cancers', 'NG','HG','HG_score_1','HG_score_2','HG_score_3','DCIS_or_LCIS','DCIS_or_LCIS_type','T_category','HER2','HER2_SISH','PR','HER2_IHC','BRCA_mutation'
]

for col_name in cat_col_names:
    cat_values = np.unique(train_df[col_name])
    
    #print(f"{col_name}: {cat_values}\n")


# 수치형 변수
num_col_names = [
    'age','size of cancers','ER_Allred_score','PR_Allred_score','KI-67_LI_percent','HER2_SISH_ratio'
]

feature_columns = (
    num_col_names + cat_col_names + target_name)

train_df = train_df.loc[:,feature_columns]


test = test_df.loc[:,num_col_names + cat_col_names]


X = train_df.loc[:,num_col_names+cat_col_names]
y = train_df.loc[:,target_name]

# %%
"""
# split the dataset into the training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = SEED)
"""


X = np.array(X)                 #np.array(df.iloc[:, :-1]) # class 열 제외한 feature 열들 모음 -> array 변환
y = np.array(y)                           #df['class']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from catboost import CatBoostClassifier

# %%
from catboost import CatBoostClassifier


from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

accuracy_history = []
f1_score_history = []

clf = CatBoostClassifier(
    max_depth = 3,
    learning_rate=0.16587542812416006,
    n_estimators=114,
    random_state=CFG['SEED']) # 모델 선언

clf.fit(X_train,y_train) # 모델 학습
y_pred=clf.predict(X_test) # 예측 라벨
accuracy_history.append(accuracy_score(y_pred, y_test)) # 정확도 측정 및 기록
f1_score_history.append(f1_score(y_pred, y_test)) # 정확도 측정 및 기록

print("accuracy 각 분할의 정확도 기록 :", accuracy_history)
print("accuracy 평균 정확도 :", np.mean(accuracy_history))

print("f1_score 각 분할의 정확도 기록 :", f1_score_history)
print("f1_score 평균 정확도 :", np.mean(f1_score_history))
# Out:
# 0:	learn: 0.6494240	total: 1.41ms	remaining: 160ms
# 1:	learn: 0.6202911	total: 2.88ms	remaining: 162ms
# 2:	learn: 0.5977459	total: 3.37ms	remaining: 125ms
# 3:	learn: 0.5777938	total: 3.88ms	remaining: 107ms
# 4:	learn: 0.5629768	total: 4.36ms	remaining: 95.1ms
# 5:	learn: 0.5484591	total: 4.82ms	remaining: 86.8ms
# 6:	learn: 0.5376646	total: 5.28ms	remaining: 80.6ms
# 7:	learn: 0.5288817	total: 5.69ms	remaining: 75.4ms
# 8:	learn: 0.5215346	total: 6.14ms	remaining: 71.6ms
# 9:	learn: 0.5146296	total: 6.67ms	remaining: 69.4ms
# 10:	learn: 0.5078736	total: 7.22ms	remaining: 67.6ms
# 11:	learn: 0.5027424	total: 7.64ms	remaining: 64.9ms
# 12:	learn: 0.4951130	total: 8.05ms	remaining: 62.6ms
# 13:	learn: 0.4899092	total: 8.39ms	remaining: 59.9ms
# 14:	learn: 0.4847034	total: 8.73ms	remaining: 57.6ms
# 15:	learn: 0.4796556	total: 9.07ms	remaining: 55.5ms
# 16:	learn: 0.4765260	total: 9.75ms	remaining: 55.6ms
# 17:	learn: 0.4745949	total: 10.3ms	remaining: 54.8ms
# 18:	learn: 0.4699631	total: 11.1ms	remaining: 55.6ms
# 19:	learn: 0.4664093	total: 11.5ms	remaining: 54.1ms
# 20:	learn: 0.4637939	total: 11.9ms	remaining: 52.6ms
# 21:	learn: 0.4616716	total: 12.2ms	remaining: 51.2ms
# 22:	learn: 0.4597845	total: 12.6ms	remaining: 49.7ms
# 23:	learn: 0.4576777	total: 12.9ms	remaining: 48.4ms
# 24:	learn: 0.4543866	total: 13.2ms	remaining: 47.1ms
# 25:	learn: 0.4530123	total: 13.6ms	remaining: 45.9ms
# 26:	learn: 0.4513197	total: 13.9ms	remaining: 44.8ms
# 27:	learn: 0.4490891	total: 14.3ms	remaining: 43.8ms
# 28:	learn: 0.4468468	total: 14.6ms	remaining: 42.8ms
# 29:	learn: 0.4452376	total: 14.9ms	remaining: 41.8ms
# 30:	learn: 0.4434526	total: 15.4ms	remaining: 41.1ms
# 31:	learn: 0.4427194	total: 15.7ms	remaining: 40.3ms
# 32:	learn: 0.4417010	total: 16.1ms	remaining: 39.5ms
# 33:	learn: 0.4409079	total: 16.4ms	remaining: 38.6ms
# 34:	learn: 0.4387498	total: 17.1ms	remaining: 38.6ms
# 35:	learn: 0.4376922	total: 17.4ms	remaining: 37.8ms
# 80:	learn: 0.3912588	total: 58.8ms	remaining: 24ms
# 81:	learn: 0.3905702	total: 59.9ms	remaining: 23.4ms
# 82:	learn: 0.3897218	total: 60.4ms	remaining: 22.6ms
# 83:	learn: 0.3892853	total: 60.9ms	remaining: 21.8ms
# 84:	learn: 0.3890225	total: 61.3ms	remaining: 20.9ms
# 85:	learn: 0.3879692	total: 61.6ms	remaining: 20.1ms
# 86:	learn: 0.3875578	total: 62ms	remaining: 19.2ms
# 87:	learn: 0.3867742	total: 63.2ms	remaining: 18.7ms
# 88:	learn: 0.3856936	total: 65ms	remaining: 18.3ms
# 89:	learn: 0.3855208	total: 66.5ms	remaining: 17.7ms
# 90:	learn: 0.3848350	total: 66.8ms	remaining: 16.9ms
# 91:	learn: 0.3846036	total: 67.2ms	remaining: 16.1ms
# 92:	learn: 0.3838795	total: 67.6ms	remaining: 15.3ms
# 93:	learn: 0.3838360	total: 67.9ms	remaining: 14.4ms
# 94:	learn: 0.3830992	total: 68.3ms	remaining: 13.7ms
# 95:	learn: 0.3830171	total: 68.6ms	remaining: 12.9ms
# 96:	learn: 0.3828771	total: 69.2ms	remaining: 12.1ms
# 97:	learn: 0.3813814	total: 69.6ms	remaining: 11.4ms
# 98:	learn: 0.3811943	total: 71.3ms	remaining: 10.8ms
# 99:	learn: 0.3804952	total: 72.2ms	remaining: 10.1ms
# 100:	learn: 0.3802685	total: 73.2ms	remaining: 9.43ms
# 101:	learn: 0.3801196	total: 73.6ms	remaining: 8.66ms
# 102:	learn: 0.3799525	total: 73.9ms	remaining: 7.9ms
# 103:	learn: 0.3794455	total: 74.3ms	remaining: 7.14ms
# 104:	learn: 0.3792898	total: 75ms	remaining: 6.43ms
# 105:	learn: 0.3785095	total: 75.4ms	remaining: 5.69ms
# 106:	learn: 0.3778049	total: 75.9ms	remaining: 4.96ms
# 107:	learn: 0.3776361	total: 77.5ms	remaining: 4.3ms
# 108:	learn: 0.3770905	total: 79.3ms	remaining: 3.64ms
# 109:	learn: 0.3762222	total: 79.7ms	remaining: 2.9ms
# 110:	learn: 0.3761891	total: 81.5ms	remaining: 2.2ms
# 111:	learn: 0.3751776	total: 83.2ms	remaining: 1.49ms
# 112:	learn: 0.3750237	total: 84.9ms	remaining: 751us
# 113:	learn: 0.3741056	total: 86.7ms	remaining: 0us
# accuracy 각 분할의 정확도 기록 : [0.788]
# accuracy 평균 정확도 : 0.788
# f1_score 각 분할의 정확도 기록 : [0.8014981273408239]
# f1_score 평균 정확도 : 0.8014981273408239

# %%
# test prediction

test_df_id = test_df.loc[:,'ID']
len(test_df_id),type(test_df_id)
array = np.array(test_df_id.values)
len(array),type(array)
test_pred = clf.predict(test)
len(test_pred),type(test_pred)
dic_pred={
    'ID' : array,
    'N_category':test_pred
}
df_test_pred = pd.DataFrame(dic_pred)
df_test_pred
f1 = np.mean(f1_score_history)
print(f1)
df_test_pred.to_csv(fr'C:\A\breastCancer\ml\output\ml/tabular_2_{f1}.csv')
# Out:
# 0.8014981273408239

# %%
# split 개수, 셔플 여부 및 seed 설정
kf = KFold(n_splits =CFG['NSPLIT'] , shuffle = True, random_state = CFG['SEED'])

# split 개수 스텝 만큼 train, test 데이터셋을 매번 분할
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %% [markdown]
# ## catboost classififier

# %%
from catboost import CatBoostClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

accuracy_history = []
f1_score_history = []

# K-fold 검증 과정으로 실제 랜덤 포레스트 모델을 학습하여 정확도 평균을 내는 방법
for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    clf = CatBoostClassifier(
      iterations=50, 
      learning_rate=0.16587542812416006, 
      loss_function='CrossEntropy',
      random_state=CFG['SEED']) # 모델 선언

    clf.fit(X_train,y_train) # 모델 학습
    y_pred=clf.predict(X_test) # 예측 라벨
    accuracy_history.append(accuracy_score(y_pred, y_test)) # 정확도 측정 및 기록
    f1_score_history.append(f1_score(y_pred, y_test)) # 정확도 측정 및 기록

print("accuracy 각 분할의 정확도 기록 :", accuracy_history)
print("accuracy 평균 정확도 :", np.mean(accuracy_history))

print("f1_score 각 분할의 정확도 기록 :", f1_score_history)
print("f1_score 평균 정확도 :", np.mean(f1_score_history))
# Out:
# 0:	learn: 0.6492950	total: 154ms	remaining: 7.56s
# 1:	learn: 0.6166632	total: 156ms	remaining: 3.73s
# 2:	learn: 0.5916543	total: 156ms	remaining: 2.45s
# 3:	learn: 0.5686702	total: 158ms	remaining: 1.81s
# 4:	learn: 0.5507858	total: 158ms	remaining: 1.43s
# 5:	learn: 0.5362503	total: 159ms	remaining: 1.17s
# 6:	learn: 0.5225605	total: 160ms	remaining: 980ms
# 7:	learn: 0.5117343	total: 160ms	remaining: 842ms
# 8:	learn: 0.5027398	total: 161ms	remaining: 734ms
# 9:	learn: 0.4931212	total: 162ms	remaining: 647ms
# 10:	learn: 0.4877906	total: 163ms	remaining: 576ms
# 11:	learn: 0.4802743	total: 163ms	remaining: 517ms
# 12:	learn: 0.4737316	total: 164ms	remaining: 467ms
# 13:	learn: 0.4693102	total: 165ms	remaining: 424ms
# 14:	learn: 0.4645107	total: 166ms	remaining: 387ms
# 15:	learn: 0.4600058	total: 166ms	remaining: 354ms
# 16:	learn: 0.4542828	total: 167ms	remaining: 324ms
# 17:	learn: 0.4503980	total: 168ms	remaining: 298ms
# 18:	learn: 0.4468582	total: 169ms	remaining: 275ms
# 19:	learn: 0.4447199	total: 169ms	remaining: 254ms
# 20:	learn: 0.4410390	total: 170ms	remaining: 235ms
# 21:	learn: 0.4386777	total: 171ms	remaining: 218ms
# 22:	learn: 0.4348951	total: 172ms	remaining: 202ms
# 23:	learn: 0.4332691	total: 172ms	remaining: 187ms
# 24:	learn: 0.4315237	total: 173ms	remaining: 173ms
# 18:	learn: 0.4369656	total: 15.4ms	remaining: 25.2ms
# 19:	learn: 0.4340368	total: 16.1ms	remaining: 24.2ms
# 20:	learn: 0.4291988	total: 17ms	remaining: 23.5ms
# 21:	learn: 0.4254578	total: 17.8ms	remaining: 22.7ms
# 22:	learn: 0.4221025	total: 18.5ms	remaining: 21.8ms
# 23:	learn: 0.4202392	total: 19.3ms	remaining: 20.9ms
# 24:	learn: 0.4168841	total: 20.1ms	remaining: 20.1ms
# 25:	learn: 0.4135011	total: 20.9ms	remaining: 19.3ms
# 26:	learn: 0.4100639	total: 22.2ms	remaining: 18.9ms
# 27:	learn: 0.4071653	total: 23.2ms	remaining: 18.2ms
# 28:	learn: 0.4053957	total: 24.3ms	remaining: 17.6ms
# 29:	learn: 0.4011134	total: 25.1ms	remaining: 16.7ms
# 30:	learn: 0.3979945	total: 25.9ms	remaining: 15.9ms
# 31:	learn: 0.3958887	total: 26.6ms	remaining: 15ms
# 32:	learn: 0.3952883	total: 27ms	remaining: 13.9ms
# 33:	learn: 0.3931414	total: 27.8ms	remaining: 13.1ms
# 34:	learn: 0.3907778	total: 28.5ms	remaining: 12.2ms
# 35:	learn: 0.3901013	total: 29.5ms	remaining: 11.5ms
# 36:	learn: 0.3876858	total: 30.6ms	remaining: 10.8ms
# 37:	learn: 0.3843937	total: 31.4ms	remaining: 9.91ms
# 38:	learn: 0.3825010	total: 32.1ms	remaining: 9.06ms
# 39:	learn: 0.3806951	total: 32.9ms	remaining: 8.22ms
# 40:	learn: 0.3783090	total: 33.6ms	remaining: 7.38ms
# 41:	learn: 0.3774702	total: 34.4ms	remaining: 6.55ms
# 42:	learn: 0.3747009	total: 35.2ms	remaining: 5.72ms
# 43:	learn: 0.3718111	total: 36.3ms	remaining: 4.96ms
# 44:	learn: 0.3699922	total: 37.1ms	remaining: 4.12ms
# 45:	learn: 0.3688981	total: 37.9ms	remaining: 3.3ms
# 46:	learn: 0.3662439	total: 38.7ms	remaining: 2.47ms
# 47:	learn: 0.3652210	total: 39.4ms	remaining: 1.64ms
# 48:	learn: 0.3639094	total: 40.1ms	remaining: 818us
# 49:	learn: 0.3618541	total: 40.9ms	remaining: 0us
# 0:	learn: 0.6494622	total: 2.19ms	remaining: 107ms
# 1:	learn: 0.6171880	total: 3.44ms	remaining: 82.6ms
# 2:	learn: 0.5895266	total: 4.31ms	remaining: 67.5ms
# 3:	learn: 0.5665340	total: 5.09ms	remaining: 58.6ms
# 4:	learn: 0.5496798	total: 5.82ms	remaining: 52.3ms
# 5:	learn: 0.5354453	total: 6.24ms	remaining: 45.8ms
# 6:	learn: 0.5247228	total: 7.01ms	remaining: 43ms
# 7:	learn: 0.5137800	total: 7.77ms	remaining: 40.8ms
# 8:	learn: 0.5040688	total: 8.54ms	remaining: 38.9ms
# 9:	learn: 0.4939502	total: 9.49ms	remaining: 38ms
# 10:	learn: 0.4868311	total: 10.3ms	remaining: 36.5ms
# 11:	learn: 0.4797206	total: 11ms	remaining: 35ms
# 12:	learn: 0.4730236	total: 11.8ms	remaining: 33.6ms
# 13:	learn: 0.4665135	total: 12.6ms	remaining: 32.4ms
# 14:	learn: 0.4615384	total: 13.3ms	remaining: 31.1ms
# 15:	learn: 0.4574963	total: 14.2ms	remaining: 30.1ms
# 16:	learn: 0.4524805	total: 15.2ms	remaining: 29.6ms
# 17:	learn: 0.4472129	total: 16.3ms	remaining: 28.9ms
# 18:	learn: 0.4435041	total: 17.1ms	remaining: 27.8ms
# 19:	learn: 0.4416443	total: 17.9ms	remaining: 26.8ms
# 20:	learn: 0.4388279	total: 18.6ms	remaining: 25.8ms
# 21:	learn: 0.4353361	total: 19.4ms	remaining: 24.7ms
# 22:	learn: 0.4310493	total: 20.2ms	remaining: 23.8ms
# 23:	learn: 0.4294044	total: 21.1ms	remaining: 22.9ms
# 24:	learn: 0.4273398	total: 22.2ms	remaining: 22.2ms
# 25:	learn: 0.4246729	total: 23ms	remaining: 21.2ms
# 26:	learn: 0.4221726	total: 23.8ms	remaining: 20.3ms
# 27:	learn: 0.4201056	total: 24.6ms	remaining: 19.3ms
# 28:	learn: 0.4163736	total: 25.4ms	remaining: 18.4ms
# 29:	learn: 0.4140709	total: 26.1ms	remaining: 17.4ms
# 30:	learn: 0.4107934	total: 26.9ms	remaining: 16.5ms
# 31:	learn: 0.4084687	total: 27.8ms	remaining: 15.6ms
# 32:	learn: 0.4041381	total: 29ms	remaining: 14.9ms
# 33:	learn: 0.4022622	total: 29.8ms	remaining: 14ms
# 34:	learn: 0.4005397	total: 30.8ms	remaining: 13.2ms
# 35:	learn: 0.3984807	total: 31.7ms	remaining: 12.3ms
# 36:	learn: 0.3962416	total: 33ms	remaining: 11.6ms
# 37:	learn: 0.3930079	total: 34ms	remaining: 10.7ms
# 38:	learn: 0.3908681	total: 35ms	remaining: 9.88ms
# 39:	learn: 0.3892262	total: 36.2ms	remaining: 9.06ms
# 40:	learn: 0.3854218	total: 37.8ms	remaining: 8.29ms
# 41:	learn: 0.3826701	total: 39.3ms	remaining: 7.48ms
# 42:	learn: 0.3810550	total: 40.6ms	remaining: 6.61ms
# 43:	learn: 0.3798277	total: 41.7ms	remaining: 5.68ms
# 44:	learn: 0.3779125	total: 43ms	remaining: 4.77ms
# 45:	learn: 0.3757108	total: 44.5ms	remaining: 3.87ms
# 46:	learn: 0.3730507	total: 45.2ms	remaining: 2.89ms
# 47:	learn: 0.3707200	total: 46.1ms	remaining: 1.92ms
# 48:	learn: 0.3679928	total: 47.3ms	remaining: 965us
# 49:	learn: 0.3654865	total: 49.8ms	remaining: 0us
# accuracy 각 분할의 정확도 기록 : [0.79, 0.75, 0.8, 0.85, 0.77, 0.86, 0.77, 0.83, 0.68, 0.72]
# accuracy 평균 정확도 : 0.7819999999999999
# f1_score 각 분할의 정확도 기록 : [0.796116504854369, 0.7619047619047618, 0.803921568627451, 0.8484848484848485, 0.7927927927927928, 0.86, 0.7628865979381443, 0.7999999999999999, 0.6666666666666666, 0.7543859649122807]
# f1_score 평균 정확도 : 0.7847159706181315

# %% [markdown]
# ## test preidiction

# %%
test_df_id = test_df.loc[:,'ID']
len(test_df_id),type(test_df_id)
# Out:
# (250, pandas.core.series.Series)

# %%
array = np.array(test_df_id.values)
len(array),type(array)
# Out:
# (250, numpy.ndarray)

# %%
test_pred = clf.predict(test)
len(test_pred),type(test_pred)
# Out:
# (250, numpy.ndarray)

# %%
dic_pred={
    'ID' : array,
    'N_category':test_pred
}

# %%
df_test_pred = pd.DataFrame(dic_pred)

# %%
df_test_pred
# Out:
#              ID  N_category
# 0    BC_01_0011         1.0
# 1    BC_01_0220         1.0
# 2    BC_01_0233         0.0
# 3    BC_01_0258         0.0
# 4    BC_01_0260         1.0
# ..          ...         ...
# 245  BC_01_3328         1.0
# 246  BC_01_3404         0.0
# 247  BC_01_3418         0.0
# 248  BC_01_3438         0.0
# 249  BC_01_3446         0.0
#
# [250 rows x 2 columns]

# %%
f1 = np.mean(f1_score_history)
print(f1)
# Out:
# 0.7847159706181315

# %%
df_test_pred.to_csv(fr'C:\A\breastCancer\ml\output\ml/tabular_2_{f1}.csv')

# %%
"""import lightgbm as lgb
clf = lgb.LGBMClassifier()
clf
clf.fit(X_train,y_train)
# predict the results
y_pred=clf.predict(X_test)
# view accuracy
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

accuracy=accuracy_score(y_pred, y_test)
print('LightGBM Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_pred)))
y_pred_train = clf.predict(X_train)
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))


# print the scores on training and test set
print('Training set score: {:.4f}'.format(clf.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf.score(X_test, y_test)))
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
f1score=f1_score(y_pred, y_test)
print('LightGBM Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_pred)))
print('LightGBM Model f1score score: {0:0.4f}'.format(f1_score(y_pred, y_test)))"""

# %%
"""from catboost import CatBoostClassifier
clf = CatBoostClassifier(
    iterations=5, 
    learning_rate=0.1, 
    loss_function='CrossEntropy'
)
clf.fit(X_train,y_train)
# predict the results
y_pred=clf.predict(X_test)
# view accuracy
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
print('catboost classififier Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_pred)))
y_pred_train = clf.predict(X_train)
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# print the scores on training and test set

print('Training set score: {:.4f}'.format(clf.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf.score(X_test, y_test)))
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
print('catboost classififier Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_pred)))"""
